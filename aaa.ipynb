# %%
printchart("#999933", "#6666FF", 16)
# Out:
# #999933
# #95953F
# #92924C
# #8F8F59
# #8C8C66
# #898972
# #85857F
# #82828C
# #7F7F99
# #7C7CA5
# #7979B2
# #7575BF
# #7272CC
# #6F6FD8
# #6C6CE5
# #6969F2
# #6666FF
